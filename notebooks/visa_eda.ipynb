# %% [markdown]
# # Canada Employment Visa Decision Support - Exploratory Data Analysis
# This notebook conducts EDA on the preprocessed applicant dataset for Canadian Employment Visa classification.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/processed/canada_employment_visa_processed.csv')
print('Dataset Shape:', df.shape)
df.head()

# %%
df['visa_outcome'].value_counts(normalize=True)
